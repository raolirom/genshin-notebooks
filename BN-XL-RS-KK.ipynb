# %% [markdown]
# #### Bennett:
# - Base Stats
#     - Base HP: <span style="color:blue">12397</span>
#     - Base ATK: <span style="color:blue">191</span>
#     - Base DEF: <span style="color:blue">771</span>
#     - ER: <span style="color:blue">26.7%</span>
#     - CRIT Rate: <span style="color:blue">5%</span>
#     - CRIT DMG: <span style="color:blue">50%</span>
# - Weapon — **Festering Desire** R5
#     - Base ATK: <span style="color:blue">510</span>
#     - ER: <span style="color:blue">45.9%</span>
#     - *Undying Admiration* — Increases Elemental Skill DMG by <span style="color:blue">32%</span> and Elemental Skill CRIT Rate by <span style="color:blue">12%</span>.
# - Artifacts
#     - 2p **Noblesse Oblige** — Elemental Burst DMG +<span style="color:blue">20%</span>.
#     - 4p **Noblesse Oblige** — Using an Elemental Burst increases all party members' ATK by <span style="color:blue">20%</span> for 12s. This effect cannot stack.
# - Q12 — *Fantastic Voyage*
#     - Characters within the Fantastic Voyage AoE gain <span style="color:blue">112%</span> of Bennett's Base ATK.
#     - Energy Cost: <span style="color:blue">60</span>
# - C1 — *Grand Expectation*
#     - Fantastic Voyage's ATK increase gains an additional <span style="color:blue">20%</span> of Bennett's Base ATK.
#
# #### Xiangling:
# - Base Stats
#     - Base HP: <span style="color:blue">10875</span>
#     - Base ATK: <span style="color:blue">225</span>
#     - Base DEF: <span style="color:blue">669</span>
#     - EM: <span style="color:blue">96</span>
#     - CRIT Rate: <span style="color:blue">5%</span>
#     - CRIT DMG: <span style="color:blue">50%</span>
# - Weapon — **Wavebreaker's Fin** R5
#     - Base ATK: <span style="color:blue">620</span>
#     - ATK Bonus: <span style="color:blue">13.8%</span>
#     - *Watatsumi Wavewalker* — For every point of the entire party's combined maximum Energy capacity, the Elemental Burst DMG of the character equipping this weapon is increased by <span style="color:blue">0.24%</span>. A maximum of <span style="color:blue">80%</span> increased Elemental Burst DMG can be achieved this way.
# - Artifacts
#     - 2p **Emblem of Severed Fate** — Energy Recharge +<span style="color:blue">20%</span>.
#     - 4p **Emblem of Severed Fate** — Increases Elemental Burst DMG by <span style="color:blue">25%</span> of Energy Recharge. A maximum of <span style="color:blue">75%</span> bonus DMG can be obtained in this way.
# - Q12 — *Pyronado*
#     - Energy Cost: <span style="color:blue">80</span>
# - A4 — *Beware, It's Super Hot!*
#     - When Guoba Attack's effects end, Guoba leaves a chili pepper on the spot where it disappeared. Picking up a chili pepper increases ATK by <span style="color:blue">10%</span> for 10s.
#     - This buff only applies to the character who picked up the chili pepper.
# - C6 — *Condensed Pyronado*
#     - For the duration of Pyronado, all party members receive a <span style="color:blue">15%</span> Pyro DMG Bonus.
#     - This buff does not apply to the Pyronado.
#
# #### Raiden Shogun:
# - Base Stats
#     - Base HP: <span style="color:blue">12907</span>
#     - Base ATK: <span style="color:blue">337</span>
#     - Base DEF: <span style="color:blue">789</span>
#     - ER: <span style="color:blue">32%</span>
#     - CRIT Rate: <span style="color:blue">5%</span>
#     - CRIT DMG: <span style="color:blue">50%</span>
# - Weapon — **"The Catch"** R5
#     - Base ATK: <span style="color:blue">510</span>
#     - ER: <span style="color:blue">45.9%</span>
#     - *Shanty* — Increases Elemental Burst DMG by <span style="color:blue">32%</span> and Elemental Burst CRIT Rate by <span style="color:blue">12%</span>.
# - Artifacts
#     - 2p **Emblem of Severed Fate** — Energy Recharge +<span style="color:blue">20%</span>.
#     - 4p **Emblem of Severed Fate** — Increases Elemental Burst DMG by <span style="color:blue">25%</span> of Energy Recharge. A maximum of <span style="color:blue">75%</span> bonus DMG can be obtained in this way.
# - E9 — *Transcendence: Baleful Omen*
#     - Characters who gain the Eye of Stormy Judgment will have their Elemental Burst DMG increased by <span style="color:blue">0.3%</span> of its Energy Cost.
# - Q9 — *Secret Art: Musou Shinsetsu*
#     - Energy Cost: <span style="color:blue">90</span>
# - A4 — *Enlightened One*
#     - Each 1% above 100% Energy Recharge that the Raiden Shogun possesses grants her a <span style="color:blue">0.4%</span> Electro DMG Bonus.
#
# #### Kaedehara Kazuha:
# - Base Stats
#     - Base HP: <span style="color:blue">13348</span>
#     - Base ATK: <span style="color:blue">297</span>
#     - Base DEF: <span style="color:blue">807</span>
#     - EM: <span style="color:blue">115.2</span>
#     - CRIT Rate: <span style="color:blue">5%</span>
#     - CRIT DMG: <span style="color:blue">50%</span>
# - Weapon — **Iron Sting** R5
#     - Base ATK: <span style="color:blue">510</span>
#     - EM: <span style="color:blue">165</span>
#     - *Infusion Stinger* — Dealing Elemental DMG increases all DMG by <span style="color:blue">12%</span> for 6s. Max 2 stacks. Can only occur once every 1s.
# - Artifacts
#     - 2p **Viridescent Venerer** — Anemo DMG Bonus +<span style="color:blue">15%</span>.
#     - 4p **Viridescent Venerer** — Increases Swirl DMG by <span style="color:blue">60%</span>. Decreases opponent's Elemental RES to the element infused in the Swirl by <span style="color:blue">40%</span> for 10s.
# - Q9 — *Kazuha Slash*
#     - Energy Cost: <span style="color:blue">60</span>
# - A4 — *Poetics of Fuubutsu*
#     - Upon triggering a Swirl reaction, Kaedehara Kazuha will grant all party members a <span style="color:blue">0.04%</span> Elemental DMG Bonus to the element absorbed by Swirl for every point of Elemental Mastery he has for 8s.
#     - Bonuses for different elements obtained through this method can co-exist.
#
# #### Elemental Resonance:
# - Pyro — *Fervent Flames*
#     - Affected by Cryo for 40% less time.
#     - Increases ATK by <span style="color:blue">25%</span>.
