# %% [markdown]
# #### Hu Tao:
# - Base Stats
#     - Base HP: <span style="color:blue">15552</span>
#     - Base ATK: <span style="color:blue">106</span>
#     - Base DEF: <span style="color:blue">876</span>
#     - CRIT Rate: <span style="color:blue">5%</span>
#     - CRIT DMG: <span style="color:blue">88.4%</span>
# - Weapon — **Staff of Homa** R1
#     - Base ATK: <span style="color:blue">608</span>
#     - CRIT DMG: <span style="color:blue">66.2%</span>
#     - *Reckless Cinnabar* — HP increased by <span style="color:blue">20%</span>. Additionally, provides an ATK Bonus based on <span style="color:blue">0.8%</span> of the wielder's Max HP. When the wielder's HP is less than 50%, this ATK bonus is increased by an additional <span style="color:blue">1%</span> of Max HP.
# - Artifacts
#     - 2p **Crimson Witch of Flames** — Pyro DMG Bonus +<span style="color:blue">15%</span>.
#     - 4p **Crimson Witch of Flames** — Increases Overloaded and Burning DMG by <span style="color:blue">40%</span>. Increases Vaporize and Melt DMG by <span style="color:blue">15%</span>. Using an Elemental Skill increases the 2-Piece Set Bonus by 50% of its starting value for 10s. Max 3 stacks.
# - ...
#
# #### Xingqiu:
# - Base Stats
#     - Base HP: <span style="color:blue">10222</span>
#     - Base ATK: <span style="color:blue">202</span>
#     - Base DEF: <span style="color:blue">758</span>
#     - ATK Bonus: <span style="color:blue">24%</span>
#     - CRIT Rate: <span style="color:blue">5%</span>
#     - CRIT DMG: <span style="color:blue">50%</span>
# - Weapon — **Sacrificial Sword** R5
#     - Base ATK: <span style="color:blue">454</span>
#     - ER: <span style="color:blue">61.3%</span>
#     - *Composed* — After dealing damage to an opponent with an Elemental Skill, the skill has a 80% chance to end its own CD. Can only occur once every 16s.
# - Artifacts
#     - 2p **Emblem of Severed Fate** — Energy Recharge +<span style="color:blue">20%</span>.
#     - 4p **Emblem of Severed Fate** — Increases Elemental Burst DMG by <span style="color:blue">25%</span> of Energy Recharge. A maximum of <span style="color:blue">75%</span> bonus DMG can be obtained in this way.
# - ...
#
# #### Zhongli:
# - Base Stats
#     - Base HP: <span style="color:blue">14695</span>
#     - Base ATK: <span style="color:blue">251</span>
#     - Base DEF: <span style="color:blue">738</span>
#     - Geo DMG Bonus: <span style="color:blue">28.8%</span>
#     - CRIT Rate: <span style="color:blue">5%</span>
#     - CRIT DMG: <span style="color:blue">50%</span>
# - Weapon — **Staff of Homa** R1
#     - Base ATK: <span style="color:blue">608</span>
#     - CRIT DMG: <span style="color:blue">66.2%</span>
#     - *Reckless Cinnabar* — HP increased by <span style="color:blue">20%</span>. Additionally, provides an ATK Bonus based on <span style="color:blue">0.8%</span> of the wielder's Max HP. When the wielder's HP is less than 50%, this ATK bonus is increased by an additional <span style="color:blue">1%</span> of Max HP.
# - Artifacts
#     - 2p **Tenacity of the Millelith** — HP +<span style="color:blue">20%</span>.
#     - 4p **Tenacity of the Millelith** — When an Elemental Skill hits an opponent, the ATK of all nearby party members is increased by <span style="color:blue">20%</span> and their Shield Strength is increased by <span style="color:blue">30%</span> for 3s. This effect can be triggered once every 0.5s. This effect can still be triggered even when the character who is using this artifact set is not on the field.
# - ...
#
# #### Albedo:
# - Base Stats
#     - Base HP: <span style="color:blue">13226</span>
#     - Base ATK: <span style="color:blue">251</span>
#     - Base DEF: <span style="color:blue">876</span>
#     - Geo DMG Bonus: <span style="color:blue">28.8</span>
#     - CRIT Rate: <span style="color:blue">5%</span>
#     - CRIT DMG: <span style="color:blue">50%</span>
# - Weapon — **Cinnabar Spindle** R5
#     - Base ATK: <span style="color:blue">454</span>
#     - DEF: <span style="color:blue">69%</span>
#     - *Spotless Heart* — Elemental Skill DMG is increased by <span style="color:blue">80%</span> of DEF. The effect will be triggered no more than once every 1.5s and will be cleared 0.1s after the Elemental Skill deals DMG.
# - Artifacts
#     - 2p **Husk of Opulent Dreams** — DEF +<span style="color:blue">30%</span>.
#     - 4p **Husk of Opulent Dreams** — A character equipped with this Artifact set will obtain the Curiosity effect in the following conditions: When on the field, the character gains 1 stack after hitting an opponent with a Geo attack, triggering a maximum of once every 0.3s. When off the field, the character gains 1 stack every 3s. Curiosity can stack up to 4 times, each providing <span style="color:blue">6%</span> DEF and a <span style="color:blue">6%</span> Geo DMG Bonus. When 6 seconds pass without gaining a Curiosity stack, 1 stack is lost.
# - ...
#
# #### Elemental Resonance:
# - Geo — *Enduring Rock*
#     - Increases shield strength by <span style="color:blue">15%</span>.
#     - DMG dealt by characters protected by a shield increases by <span style="color:blue">15%</span>.
#     - When a character protected by a shield deals DMG to enemies, their GEO Res decreases by <span style="color:blue">20%</span> for 15s.
